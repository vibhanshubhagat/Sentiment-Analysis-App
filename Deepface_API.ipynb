# %%
#!pip install deepface

# %%
from deepface import DeepFace

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img1 = cv2.imread('/Users/vibhanshubhagat/Desktop/ML/Sentiment Analysis/image16.jpg')
plt.imshow(img1[:,:,::-1])
plt.show()

# %%
result = DeepFace.analyze(img1, actions = ['emotion'])
print(result)
dominant_emotion = result[0]['dominant_emotion']
print("Dominant emotion:", dominant_emotion)
# Out:
# Action: emotion: 100%|████████████████████████████| 1/1 [00:00<00:00,  8.37it/s]
# [{'emotion': {'angry': 0.04573761525303812, 'disgust': 1.8759195316161025e-08, 'fear': 0.031429382633865334, 'happy': 4.197684938935236e-06, 'sad': 98.8943039711895, 'surprise': 8.2112446740255e-09, 'neutral': 1.0285262631491578}, 'dominant_emotion': 'sad', 'region': {'x': 97, 'y': 14, 'w': 211, 'h': 211}}]
# Dominant emotion: sad

# %%
# from flask import Flask, request, jsonify
# from deepface import DeepFace
# import cv2
# import numpy as np

# app = Flask(__name__)

# @app.route('/')
# def home():
#     return "Welcome to the Emotion Analysis API:)"

# #@app.route('/vibhanshu')
# # def hi():
# #     string_base64 = "..."
# #     image_array = np.frombuffer(image_bytes, np.uint8)

# #     # Decode the image using OpenCV
# #     image = cv2.imdecode(image_array, cv2.IMREAD_COLOR)
    
# #     # Perform emotion analysis using DeepFace
# #     result = DeepFace.analyze(image, actions=['emotion'])
    
# #     # Extract the dominant emotion
# #     dominant_emotion = result[0]['dominant_emotion']
    
# #     # Prepare the response
# #     response = {
# #         'dominant_emotion': dominant_emotion
# #     }
    
# #     return dominant_emotion 
    

# @app.route('/analyze_emotion', methods=['POST'])
# def analyze_emotion():
#     data = request.stream.read
#     return data

# if __name__ == '__main__':
#     app.run(debug=False, host='0.0.0.0', port=5003)

# %%
# from flask import Flask, request, jsonify

# app = Flask(__name__)

# @app.route('/')
# def home():
#     return "Welcome to the Emotion Analysis API:)"

# @app.route('/analyze_emotion', methods=['POST'])
# def analyze_emotion():
#     data = request.stream.read(1024)
#     return jsonify(data)

# if __name__ == '__main__':
#     app.run(debug=False, host='0.0.0.0', port=5003)

# %%
# from flask import Flask, request, json
# import numpy as np

# app = Flask(__name__)

# @app.route('/post_json', methods=['POST'])
# def process_json():
#     data = json.loads(request.data)
#     image_array = np.frombuffer(data['byte_string'], np.uint8)

#     # Decode the image using OpenCV
#     image = cv2.imdecode(image_array, cv2.IMREAD_COLOR)
    
#     # Perform emotion analysis using DeepFace
#     result = DeepFace.analyze(image, actions=['emotion'])
    
#     # Extract the dominant emotion
#     dominant_emotion = result[0]['dominant_emotion']
    
#     # Prepare the response
#     response = {
#         'dominant_emotion': dominant_emotion
#     }
#     print(dominant_emotion)
#     return dominant_emotion 

# if __name__ == '__main__':
#      app.run(debug=False, host='0.0.0.0', port=5003)
        
# print(dominant_emotion)

# %%
# from flask import Flask, request, json
# import numpy as np
# import cv2
# from deepface import DeepFace
# import base64

# app = Flask(__name__)

# @app.route('/post_json', methods=['POST'])
# def process_json():
#     data = json.loads(request.data)

#     # Decode the image using OpenCV
#     imgdata = base64.b64decode(data['byte_string'])
#     image_array = np.frombuffer(imgdata, np.uint8)

#     # Decode the image using OpenCV
#     image = cv2.imdecode(image_array, cv2.IMREAD_COLOR)
    
#     # Perform emotion analysis using DeepFace
#     result = DeepFace.analyze(image, actions=['emotion'])

    
#     # Extract the dominant emotion
#     dominant_emotion = result[0]['dominant_emotion']
    
#     # Prepare the response
    
    
#     return dominant_emotion

# if __name__ == '__main__':
#      app.run(debug=False, host='0.0.0.0', port=5003)

# %%
from flask import Flask, request, json
import numpy as np
import cv2
from deepface import DeepFace
import base64

app = Flask(__name__)

@app.route('/')
def home():
    return "Welcome to the Emotion Analysis API:)"

@app.route('/post_json', methods=['POST'])
def process_json():
    data = request.get_json()

    # Add padding characters if necessary
    padding = len(data['byte_string']) % 4
    if padding != 0:
        data['byte_string'] += '=' * (4 - padding)

    # Decode the image using OpenCV
    imgdata = base64.b64decode(data['byte_string'])
    image_array = np.frombuffer(imgdata, np.uint8)

    # Decode the image using OpenCV
    image = cv2.imdecode(image_array, cv2.IMREAD_COLOR)
    
    # Perform emotion analysis using DeepFace
    result = DeepFace.analyze(image, actions=['emotion'])

    # Extract the dominant emotion
    dominant_emotion = result[0]['dominant_emotion']
    
    return dominant_emotion

if __name__ == '__main__':
     app.run(debug=False, host='0.0.0.0', port=5003)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5003
#  * Running on http://192.168.0.72:5003
# Press CTRL+C to quit
# Action: emotion: 100%|████████████████████████████| 1/1 [00:00<00:00,  4.09it/s]
# 127.0.0.1 - - [05/Jul/2023 03:13:07] "POST /post_json HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jul/2023 03:14:38] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Jul/2023 03:14:38] "GET / HTTP/1.1" 200 -
# Action: emotion: 100%|████████████████████████████| 1/1 [00:00<00:00,  2.42it/s]
# 127.0.0.1 - - [05/Jul/2023 03:15:35] "POST /post_json HTTP/1.1" 200 -
# Action: emotion: 100%|████████████████████████████| 1/1 [00:00<00:00, 17.32it/s]
# 127.0.0.1 - - [05/Jul/2023 03:15:40] "POST /post_json HTTP/1.1" 200 -
# Action: emotion: 100%|████████████████████████████| 1/1 [00:00<00:00, 14.23it/s]
# 127.0.0.1 - - [05/Jul/2023 03:15:47] "POST /post_json HTTP/1.1" 200 -
